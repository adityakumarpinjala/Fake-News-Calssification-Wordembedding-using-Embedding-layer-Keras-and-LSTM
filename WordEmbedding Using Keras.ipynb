# %%
import tensorflow
from tensorflow.keras.preprocessing.text import one_hot  # in 2.0, Here Keras is integrated with tensorflow

# %%
sent=['the glass of milk','the glass of juice',
      'the cup of tea','iam a good boy',
      'iam good a good developer','understanding the meaning of words','your vedios are good' ]

# %%
vocab_size=10000
#index from the dictionary
one_repre=[one_hot(snt,vocab_size) for snt in sent]
one_repre
# Out:
# [[6022, 5573, 7136, 1195],
#  [6022, 5573, 7136, 1455],
#  [6022, 3701, 7136, 5279],
#  [2925, 7210, 1097, 6845],
#  [2925, 1097, 7210, 1097, 2212],
#  [3465, 6022, 7835, 7136, 1632],
#  [3340, 5273, 8615, 1097]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
sent_lenght=8
embeded_docs=pad_sequences(one_repre,padding='pre',maxlen=sent_lenght)

# %%
embeded_docs
# Out:
# array([[   0,    0,    0,    0, 6022, 5573, 7136, 1195],
#        [   0,    0,    0,    0, 6022, 5573, 7136, 1455],
#        [   0,    0,    0,    0, 6022, 3701, 7136, 5279],
#        [   0,    0,    0,    0, 2925, 7210, 1097, 6845],
#        [   0,    0,    0, 2925, 1097, 7210, 1097, 2212],
#        [   0,    0,    0, 3465, 6022, 7835, 7136, 1632],
#        [   0,    0,    0,    0, 3340, 5273, 8615, 1097]])

# %%
dimensions=10

# %%
model=Sequential()
model.add(Embedding(vocab_size,dimensions,input_length=sent_lenght))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 8, 10)             100000
# ...
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
X=print(model.predict(embeded_docs))
# Out:
# [[[ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#     1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#     4.05657291e-03  4.62963246e-02]
#   [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#     1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#     4.05657291e-03  4.62963246e-02]
#   [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#     1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#     4.05657291e-03  4.62963246e-02]
#   [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#     1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#     4.05657291e-03  4.62963246e-02]
#   [-3.19304615e-02  3.53735127e-02  4.75506894e-02 -1.23576894e-02
#     1.42747201e-02  4.23742458e-03 -2.48414036e-02 -1.13125555e-02
#    -5.85119799e-03 -1.50949843e-02]
#   [ 2.18168981e-02 -3.31517309e-03  4.65711020e-02  3.96668650e-02
# ...

# %%
print(model.predict(embeded_docs)[0])
# Out:
# [[ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#    1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#    4.05657291e-03  4.62963246e-02]
#  [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#    1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#    4.05657291e-03  4.62963246e-02]
#  [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#    1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#    4.05657291e-03  4.62963246e-02]
#  [ 4.92700003e-02 -3.75286229e-02 -2.35474240e-02  4.08678092e-02
#    1.21006593e-02  2.44091861e-02  3.36841010e-02 -4.67562936e-02
#    4.05657291e-03  4.62963246e-02]
#  [-3.19304615e-02  3.53735127e-02  4.75506894e-02 -1.23576894e-02
#    1.42747201e-02  4.23742458e-03 -2.48414036e-02 -1.13125555e-02
#   -5.85119799e-03 -1.50949843e-02]
#  [ 2.18168981e-02 -3.31517309e-03  4.65711020e-02  3.96668650e-02
# ...
